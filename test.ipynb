# %%
# !pip install torch
# Out:
# ^C
# ...
#    ---------------------------------------- 0.0/159.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/159.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/159.7 MB 330.3 kB/s eta 0:08:04
#    ---------------------------------------- 0.1/159.7 MB 751.6 kB/s eta 0:03:33
#    ---------------------------------------- 0.2/159.7 MB 1.1 MB/s eta 0:02:32
#    ---------------------------------------- 0.3/159.7 MB 1.3 MB/s eta 0:02:07
#    ---------------------------------------- 0.3/159.7 MB 1.4 MB/s eta 0:01:58
#    ---------------------------------------- 0.5/159.7 MB 1.5 MB/s eta 0:01:48
#    ---------------------------------------- 0.6/159.7 MB 1.6 MB/s eta 0:01:40
#    ---------------------------------------- 0.6/159.7 MB 1.6 MB/s eta 0:01:42
#    ---------------------------------------- 0.7/159.7 MB 1.6 MB/s eta 0:01:43
#    ---------------------------------------- 0.7/159.7 MB 1.6 MB/s eta 0:01:43
# ...

# %%
import torch

mm = torch.cuda.get_device_properties(0).total_memory
print(mm)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\Users\DR2\Desktop\IASD\S2\NLP\llm test\rag-tutorial-v2\test.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/DR2/Desktop/IASD/S2/NLP/llm%20test/rag-tutorial-v2/test.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import torch
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DR2/Desktop/IASD/S2/NLP/llm%20test/rag-tutorial-v2/test.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> mm = torch.cuda.get_device_properties(0).total_memory
#       <a href='vscode-notebook-cell:/c%3A/Users/DR2/Desktop/IASD/S2/NLP/llm%20test/rag-tutorial-v2/test.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> print(mm)
#
# File c:\Users\DR2\AppData\Local\Python312\Lib\site-packages\torch\cuda\__init__.py:453, in get_device_properties(device)
#     443 def get_device_properties(device: _device_t) -> _CudaDeviceProperties:
#     444     r"""Get the properties of a device.
# ...
